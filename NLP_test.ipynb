# %%
import pandas as pd

df=pd.read_excel('data.xlsx')

# %%
import requests

API_KEY='sk-c749d369622646aeaf909f89b33e2648'

SYSTEM_PROMPT="You're given data about a lead's business and you're required to generate a persuasive whatsapp message offering a service for SEO and Web developement"

USER_PROMPT="""
Name	Phone	Email	Website	AverageRating	RatingCount	OneStarCount	TwoStarCount	ThreeStarCount	FourStarCount	FiveStarCount	
MODEL='deepseek-reasoner'
URL="https://api.deepseek.com/v1/chat/completions"
TEMPERATURE=0.0

# %%
headers={
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
    }
payload={
    "model":MODEL,
    "messages":[
    {"role": "system", "content": SYSTEM_PROMPT},
    {"role": "user", "content": USER_PROMPT}
    ],  
    "temperature": TEMPERATURE
}

# %%
response=requests.post(url=URL,json=payload,headers=headers)

# %%
print(response.json()['choices'][0]['message']['content'])
# Out:
# **Subject: Boost Your Premium Limousine Service with a Professional Online Presence**
#
# Hi there! 👋
#
# I hope this message finds you well. I came across DDT LimOUSINES on Google and was impressed by your perfect 5-star rating with 11 glowing reviews – that's a fantastic achievement! It’s clear your clients love the premium experience you provide.
#
# However, I noticed there’s an opportunity to further expand your reach and attract even more high-end clients. Many customers today search online for luxury transportation, and without a strong website and optimized online presence, you might be missing out on valuable bookings.
#
# That's where we can help. Our team specializes in **SEO (Search Engine Optimization)** and **custom web development** to ensure businesses like yours stand out. Here’s what we can do for you:
#
# 🔹 **Build a sleek, professional website** that reflects the luxury and reliability of DDT LimOUSINES.
# ...
